# %%
from collections import Counter
from typing import List, Callable, Optional

import spacy
import torch
import torchtext
import pandas as pd
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader
# Out:
# /usr/local/lib/python3.10/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.10/dist-packages/torchtext/utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)

# %%
english_language = spacy.load('en_core_web_sm')  # Utilizaremos spaCy para la tokenización

# %% [markdown]
# # 1. Introducción

# %% [markdown]
# En este cuaderno abordarás la tarea de inversión de oraciones. Aunque no posee una aplicación práctica inmediata, este ejercicio te permitirá explorar y familiarizarte con la arquitectura transformer. El objetivo consiste en invertir el orden de las palabras en una oración; por ejemplo, ante una entrada tokenizada ["hola", "mundo", "!"], se espera que el modelo genere ["!", "mundo", "hola"] como resultado.
#
# Para el conjunto de datos usaremos el archivo `open_subtitles_english.txt` el cual ya habíamos utilizado en el cuaderno de `machine translation` utilizando la red LSTM.

# %% [markdown]
# # 2. Creación del Vocabulario

# %% [markdown]
# En esta sección tienes que crear un vocabulario utilizando torchtext. El vocabulario tiene que tener 10,000 + 4 palabras. El +4 es debido a los tokens especiales `<sos>`, `<eos>`, `<unk>` y `<pad>`. El 10,000 significa que tomaremos las 10,000 palabras más frecuentes en el conjunto de datos.

# %%
def read_file_into_lines(filename: str) -> List[str]:
    with open(filename, "rt") as f:
        lines = f.readlines()
    lines = [l.strip() for l in lines]
    return lines


lines = read_file_into_lines("open_subtitles_english.txt")
single_line = " ".join(lines)
english_language.max_length = len(single_line)
document = english_language(single_line, disable=['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner'])
tokenized_single_line = [token.text for token in document]

vocabulary = build_vocab_from_iterator([tokenized_single_line], max_tokens=10_000)
vocabulary.append_token("<unk>")
vocabulary.append_token("<sos>")
vocabulary.append_token("<eos>")
vocabulary.append_token("<pad>")

# %%
print(f"len(vocabulary): {len(vocabulary):,}")  # len(vocabulary): 10,004
# Out:
# len(vocabulary): 10,004

# %% [markdown]
# # 3. Definición de Dataset y Dataloader

# %% [markdown]
# En esta sección definirás el `torch.utils.data.Dataset` y `torch.utils.data.Dataloader`. El `Dataset` debe de entregar la i-ésima oración del conjunto de datos como un arreglo de `PyTorch`. Se espera recibir una función opcional que recibe un conjunto de oraciones de tipo List[str] y realiza las siguientes transformaciones:
# 1. Convierte las oraciones a minúsculas.
# 2. Tokeniza las oraciones utilizando spaCy.
# 3. Agrega tokens espaciales `<sos>`, `<eos>`, `<unk>`.
# 4. Convierte los símbolos de cada oración en índices.

# %%
class SentenceInversionDataset(torch.utils.data.Dataset):
    def __init__(self, filename: str, transform: Optional[Callable]):
        """Dataset para la tarea de inversión de oraciones.
        :param filename: Path to the txt file with all data.
        """
        self._lines: List[str] = read_file_into_lines(filename)
        if transform:
            self._lines = transform(self._lines)

    def __len__(self):
        return len(self._lines)

    def __getitem__(self, idx: int) -> torch.tensor:
        return torch.tensor(self._lines[idx])

# %%
class Compose:
    def __init__(self, transforms: List[Callable]):
        self._transforms = transforms

    def __call__(self, sentences: List[str]) -> None:
        for t in self._transforms:
            sentences = t(sentences)
        return sentences


class ToLowerCase:
    def __call__(self, sentences: List[str]) -> List[str]:
        new_sentences = []
        for s in sentences:
            new_sentences.append(s.lower())
        return new_sentences


class Tokenize:
    def __init__(self, language: spacy.Language) -> None:
        self._language = language

    def __call__(self, sentences: List[str]) -> List[List[str]]:
        tokenized_lines = []
        for i, document in enumerate(self._language.pipe(sentences, disable=['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner'])):
            tokenized_lines.append([token.text for token in document])
        return tokenized_lines


class InsertSpecialTokens:
    def __init__(self, vocabulary) -> None:
        self._vocabulary = vocabulary

    def __call__(self, tokenized_sentences: List[List[str]]) -> List[List[str]]:
        new_sentences = []
        for ts in tokenized_sentences:
            new_sentences.append(["<sos>"] + [token if token in self._vocabulary else "<unk>" for token in ts] + ["<eos>"])
        return new_sentences


class SymbolToIndex:
    def __init__(self, vocabulary) -> None:
        self._vocabulary = vocabulary

    def __call__(self, tokenized_sentences: List[List[str]]) -> List[List[int]]:
        new_sentences = []
        for ts in tokenized_sentences:
            new_sentences.append([self._vocabulary[token] for token in ts])
        return new_sentences


test = ["Hello World !", "this is another test sentence"]
transform = Compose(transforms=[ToLowerCase(), Tokenize(english_language), InsertSpecialTokens(vocabulary), SymbolToIndex(vocabulary)])
print(transform(test))
# Out:
# [[10001, 837, 286, 11, 10002], [10001, 31, 21, 296, 2180, 2443, 10002]]

# %%
# Initialize dataset
transform = Compose(transforms=[ToLowerCase(), Tokenize(english_language), InsertSpecialTokens(vocabulary), SymbolToIndex(vocabulary)])
dataset = SentenceInversionDataset("open_subtitles_english.txt", transform)


# Inicializar el DataLoader
def collate_fn(batch: List[torch.tensor]):
    # idea, create inverted batch and then pad the target
    inverted_batch = [torch.flip(x, [0]) for x in batch]
    input = torch.nn.utils.rnn.pad_sequence(batch, batch_first=True, padding_value=vocabulary["<pad>"])
    target = torch.nn.utils.rnn.pad_sequence(inverted_batch, batch_first=True, padding_value=vocabulary["<pad>"])
    return {'input': input, 'target': target}


dataloader = DataLoader(dataset, batch_size=256, shuffle=True, collate_fn=collate_fn, drop_last=True)

# %%
print(f"next(iter(dataloader))['input'].dtype: {next(iter(dataloader))['input'].dtype}")
# Out:
# next(iter(dataloader))['input'].dtype: torch.int64

# %%
print(f"next(iter(dataloader))['target'].dtype: {next(iter(dataloader))['target'].dtype}")
# Out:
# next(iter(dataloader))['target'].dtype: torch.int64

# %% [markdown]
# # 4. Definición del Modelo

# %%
class TransformerModel(torch.nn.Module):
    def __init__(
        self,
        vocab_size: int,
        d_model: int,
        nhead: int,
        num_encoder_layers: int,
        num_decoder_layers: int,
        max_seq_length: int,
        dropout=0.1) -> None:
        super().__init__()
        self.d_model = d_model
        self.embedding = torch.nn.Embedding(vocab_size, d_model)
        self.pos_encoder = torch.nn.Embedding(max_seq_length, d_model)
        self.transformer = torch.nn.Transformer(
            d_model=d_model,
            nhead=nhead,
            num_encoder_layers=num_encoder_layers,
            num_decoder_layers=num_decoder_layers,
            dropout=dropout,
            batch_first=True
        )
        # Output linear layer to project back to vocab size
        self.fc_out = torch.nn.Linear(d_model, vocab_size)

        # Positions for positional encoding
        self.positions = torch.arange(max_seq_length).unsqueeze(0)  # [1, max_seq_length]  [[0, 1, 2, 3, 4, 5]]

    def forward(self, src, tgt):
        # src and tgt shapes: [batch_size, seq_length]
        src_seq_length = src.size(1)
        tgt_seq_length = tgt.size(1)

        src_key_padding_mask = (src == vocabulary["<pad>"]).to(torch.bool)
        tgt_key_padding_mask = (tgt == vocabulary["<pad>"]).to(torch.bool)

        # Generate positional indices for src and tgt
        src_positions = self.positions[:, :src_seq_length].to(src.device)  # [1, src_seq_length]
        tgt_positions = self.positions[:, :tgt_seq_length].to(tgt.device)  # [1, tgt_seq_length]

        # Add embedding and positional encoding
        src = self.embedding(src) + self.pos_encoder(src_positions)  # [batch_size, src_seq_length, d_model]
        tgt = self.embedding(tgt) + self.pos_encoder(tgt_positions)  # [batch_size, tgt_seq_length, d_model]

        # Forward pass through transformer
        tgt_mask = torch.nn.Transformer.generate_square_subsequent_mask(tgt_seq_length, device=tgt.device)

        output = self.transformer(
            src=src,
            tgt=tgt,
            tgt_mask=tgt_mask,
            src_key_padding_mask=src_key_padding_mask,  # [N, S]
            tgt_key_padding_mask=tgt_key_padding_mask,  # [N, T]
            # memory_key_padding_mask=src_key_padding_mask,
            # tgt_is_causal=True
        )  # [batch_size, tgt_seq_length, d_model]

        output = self.fc_out(output)  # [batch_size, tgt_seq_length, vocab_size]

        return output

# %%
# Example model initialization
vocab_size = len(vocabulary)  # Size of your vocabulary
d_model = 512  # Embedding dimension
nhead = 8  # Number of attention heads
num_encoder_layers = 3  # Number of encoder layers
num_decoder_layers = 3  # Number of decoder layers
max_seq_length = 200  # Maximum sequence length
dropout = 0.1  # Dropout rate

# Model definition
model = TransformerModel(vocab_size, d_model, nhead, num_encoder_layers, num_decoder_layers, max_seq_length, dropout)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# Loss Function
criterion = torch.nn.CrossEntropyLoss(ignore_index=vocabulary["<pad>"])

# %%
def predict(
    model: torch.nn.Module,
    sentence: torch.tensor,  # [1, L]
    vocabulary: torchtext.vocab.Vocab,
    device,
    max_seq_length: int = 50,
) -> str:
    sentence.to(device)
    model.eval()
    with torch.no_grad():
        # Generate target sequence
        tgt_indices = [vocabulary["<eos>"]]  # Target sequence starts with <eos>
        for _ in range(max_seq_length - 1):
            tgt_tensor = torch.tensor(tgt_indices, dtype=torch.long).unsqueeze(0).to(device)
            output = model(sentence, tgt_tensor)

            # Take the most likely word from the last position of the tgt sequence
            next_word_logits = output[0, -1, :]  # Shape: [vocab_size]
            next_word_index = next_word_logits.argmax().item()
            tgt_indices.append(next_word_index)

            if next_word_index == vocabulary["<sos>"]:
                break

    model.train()
    input_sentence_string =" ".join([vocabulary.lookup_token(index) for index in sentence[0] if index != vocabulary["<pad>"]])
    output_sentence_string = " ".join([vocabulary.lookup_token(index) for index in tgt_indices])
    return input_sentence_string, output_sentence_string

# %%
def train(model, dataloader, optimizer, criterion, num_epochs=10):
    model.train()  # set model to training mode

    for epoch in range(num_epochs):
        epoch_loss = 0

        for i, batch in enumerate(dataloader):
            src = batch["input"].to(device)  # [batch_size, src_seq_length]
            tgt = batch["target"].to(device)  # [batch_size, tgt_seq_length]

            # Forward pass
            # The target sequence `tgt` is both what we compare against (labels) and input as part of the decoder input
            # We need to shift the decoder's input to include the <sos> token and exclude the <eos> token from the inputs
            tgt_input = tgt[:, :-1]
            labels = tgt[:, 1:]  # Exclude <sos> token for labels [batch_size, tgt_seq_length]

            optimizer.zero_grad()
            output = model(src, tgt_input)  # [batch_size, tgt_seq_length - 1, vocab_size]

            # Reshape output to fit into CrossEntropyLoss
            output_dim = output.shape[-1]
            output = output.view(-1, output_dim)  # [batch_size * (tgt_seq_length - 1), vocab_size]
            labels = labels.view(-1)  # [batch_size * (tgt_seq_length - 1)]

            # import pdb; pdb.set_trace()
            loss = criterion(output, labels)
            loss.backward()  # Backpropagation
            optimizer.step()  # Update the optimizer

            if i % 50 == 0:
                print(f"\tloss: {loss.item()}")
                input_sentence, output_sentence = predict(model, src[[0], :], vocabulary, device)
                print(f"\tinput_sentence: {input_sentence}")
                print(f"\toutput_sentence: {output_sentence}")

            epoch_loss += loss.item() * labels.size(0)  # Multiply by the number of entries

        epoch_loss /= len(dataloader.dataset)  # Average the loss

        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}')

# Call the training function
train(model, dataloader, optimizer, criterion, num_epochs=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5109: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# 	loss: 0.028363779187202454
# 	input_sentence: <sos> - <unk> ... ah , hey <unk> , <eos>
# 	output_sentence: <eos> , <unk> hey , ah ... <unk> - , ah ... <unk> - , <unk> - , <unk> - , <unk> - <sos>
# 	loss: 0.027767186984419823
# 	input_sentence: <sos> why did i ever get myself mixed up in this mess ? <eos>
# 	output_sentence: <eos> ? mess this in up mixed myself get ever i did why ? mess this did why did why did why did why <sos>
# 	loss: 0.03434755653142929
# 	input_sentence: <sos> there it is . <eos>
# 	output_sentence: <eos> . is it there . is it there there there there there there there there there there there there there there <sos>
# 	loss: 0.016844915226101875
# 	input_sentence: <sos> for our country will never make war we have a reason that 's worth marching for <eos>
# 	output_sentence: <eos> for marching worth 's that reason a have we war make never will country our for country our for country our for <sos>
# 	loss: 0.028306610882282257
# 	input_sentence: <sos> <unk> <eos>
# 	output_sentence: <eos> <unk> to sick , say and <unk> these to able a <unk> who <unk> <sos>
# 	loss: 0.03295132890343666
# 	input_sentence: <sos> let him come up immediately ! <eos>
# 	output_sentence: <eos> ! immediately up come him come him let him let him let him let him let him let him let him let him let <sos>
# 	loss: 0.023256700485944748
# 	input_sentence: <sos> - <unk> , <unk> . <eos>
# 	output_sentence: <eos> . <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> - . <unk> - . <unk> - <sos>
# 	loss: 0.030698221176862717
# 	input_sentence: <sos> how do i know you 're a real <unk> officer ? <eos>
# 	output_sentence: <eos> ? officer <unk> real a 're you know i do how ? officer how do how <sos>
# 	loss: 0.02533491887152195
# 	input_sentence: <sos> help me to give him up . <eos>
# 	output_sentence: <eos> . up him give to me help to me help to me help to me help to me help to me help help help help help help help help help help <sos>
# 	loss: 0.034392982721328735
# 	input_sentence: <sos> hello , <unk> . <eos>
# 	output_sentence: <eos> . <unk> , hello , hello , hello , hello , hello , hello , hello , hello , hello , hello <sos>
# 	loss: 0.022171886637806892
# 	input_sentence: <sos> she might come here at any moment . <eos>
# 	output_sentence: <eos> . moment any at here come might she . moment any at here come might she might she might she might she might she might she <sos>
# 	loss: 0.02800816297531128
# 	input_sentence: <sos> that ought to draw them , all right . <eos>
# 	output_sentence: <eos> . right all , them draw to ought that . right all draw to ought that . to ought that ought that <sos>
# 	loss: 0.014745179563760757
# 	input_sentence: <sos> keep the change . <eos>
# 	output_sentence: <eos> . change the keep change . change to change never . change the keep the keep the keep <sos>
# 	loss: 0.021384114399552345
# 	input_sentence: <sos> yes , is n't she lovely ? <eos>
# 	output_sentence: <eos> ? lovely she n't is , yes she n't is , yes she n't is , yes she n't is , yes <sos>
# 	loss: 0.04415608569979668
# 	input_sentence: <sos> and a wife makes a slave of you . <eos>
# 	output_sentence: <eos> . you of slave a makes wife wife wife wife wife wife wife wife wife wife wife wife wife a and . a and . a and a and <sos>
# 	loss: 0.020057108253240585
# 	input_sentence: <sos> <unk> , is a fight on ? <eos>
# 	output_sentence: <eos> ? on fight a is , <unk> fight a is , fight a is , <unk> <unk> is , <unk> <unk> <sos>
# 	loss: 0.03242511674761772
# 	input_sentence: <sos> - here 's a pip . <eos>
# 	output_sentence: <eos> . pip a 's here - . pip a 's here - . pip a 's here - - - - - <sos>
# 	loss: 0.03216547891497612
# 	input_sentence: <sos> suppose you find out the boy is n't guilty ... and that my record is clean and clear of anything like this . <eos>
# 	output_sentence: <eos> . this like anything of clear and clean is record my that and ... guilty n't is boy the out find you suppose you suppose <sos>
# 	loss: 0.026845017448067665
# 	input_sentence: <sos> they say she 's much too good for me . <eos>
# 	output_sentence: <eos> . me for good too much 's she say they say they say 's she say they say 's she say they say they say they say they say they they say they say they they say they they they say they they they they they <sos>
# 	loss: 0.014586865901947021
# 	input_sentence: <sos> - maybe we could get married now . <eos>
# 	output_sentence: <eos> . now married get get could we maybe - . now married married get could we maybe - now we maybe - maybe - maybe - <sos>
# 	loss: 0.025033826008439064
# 	input_sentence: <sos> you must come over . <eos>
# 	output_sentence: <eos> . over come must you over come must you must come must you must you must you must you must you must you <sos>
# 	loss: 0.02228529565036297
# 	input_sentence: <sos> if you 're interested , come into my <unk> and <unk> show you . <eos>
# 	output_sentence: <eos> . you show <unk> and <unk> my into come , interested 're you if . you if <sos>
# 	loss: 0.014901047572493553
# 	input_sentence: <sos> we must strike now . <eos>
# 	output_sentence: <eos> . now strike must we . now strike strike strike strike must must strike strike must must we <sos>
# 	loss: 0.02052474580705166
# 	input_sentence: <sos> not the kind of love i 've seen is n't . <eos>
# 	output_sentence: <eos> . n't is seen 've i love of kind the not . n't is the not . n't not <sos>
# 	loss: 0.025369912385940552
# 	input_sentence: <sos> stand by , <unk> , for full returns . <eos>
# 	output_sentence: <eos> . returns full for , <unk> , by stand full for , <unk> , by stand , by stand , by stand , by stand , by stand stand stand stand stand stand stand stand stand stand stand stand stand <sos>
# 	loss: 0.01943182945251465
# 	input_sentence: <sos> indeed , mrs . <unk> ? <eos>
# 	output_sentence: <eos> ? <unk> . mrs , indeed <unk> . <unk> . mrs , indeed . mrs , indeed , indeed , indeed , indeed , indeed , indeed <sos>
# 	loss: 0.019247720018029213
# 	input_sentence: <sos> - we 'll make him tell . <eos>
# 	output_sentence: <eos> . tell him make 'll we - tell him make 'll we - tell him make 'll we - tell 'll we - <sos>
# 	loss: 0.01813087984919548
# 	input_sentence: <sos> but he will have one before we arrive in <unk> . <eos>
# 	output_sentence: <eos> . <unk> in arrive we before one have will he but <sos>
# 	loss: 0.036382462829351425
# 	input_sentence: <sos> it 's funny how simple people get strange ideas about women . <eos>
# 	output_sentence: <eos> . women about ideas strange strange get people simple how funny 's it about women about it <sos>
# 	loss: 0.013276874087750912
# 	input_sentence: <sos> - it should , but <unk> . <unk> is changed . <eos>
# 	output_sentence: <eos> . changed is <unk> . <unk> but , should it - changed is <unk> . changed is <unk> . changed it - <sos>
# 	loss: 0.011743569746613503
# 	input_sentence: <sos> if <unk> has the <unk> , try a <unk> with mustard flour . <eos>
# 	output_sentence: <eos> . flour mustard with <unk> a try , <unk> the has <unk> if . flour mustard with <unk> if <unk> if <unk> if <sos>
# 	loss: 0.014867493882775307
# 	input_sentence: <sos> - also regret marriage very unhappy . <eos>
# 	output_sentence: <eos> . unhappy very marriage regret also - . unhappy - unhappy very marriage marriage marriage regret also - also - also - also - also - <sos>
# 	loss: 0.013889411464333534
# 	input_sentence: <sos> they hit our right motor . <eos>
# 	output_sentence: <eos> . motor right our hit they . motor right our hit they our hit they our hit they our hit they <sos>
# 	loss: 0.011910035274922848
# 	input_sentence: <sos> oh , that 's very nice . <eos>
# 	output_sentence: <eos> . nice very 's that , nice very 's that , nice very 's that , oh <sos>
# 	loss: 0.014718113467097282
# 	input_sentence: <sos> - i could go for another one . <eos>
# 	output_sentence: <eos> . one another for go could i - one another for go could i - <sos>
# 	loss: 0.01420949399471283
# 	input_sentence: <sos> madame ... <eos>
# 	output_sentence: <eos> ... madame madame <unk> , madame and ... madame <unk> ... madame great ... madame <sos>
# 	loss: 0.019693074747920036
# 	input_sentence: <sos> i 'm glad you 're not your friend , professor van <unk> . <eos>
# 	output_sentence: <eos> . <unk> van professor , friend your not 're you glad 'm i <sos>
# 	loss: 0.016114065423607826
# 	input_sentence: <sos> <unk> bye . <eos>
# 	output_sentence: <eos> . bye <unk> . bye <unk> because bye <unk> if . bye <unk> <sos>
# 	loss: 0.013423899188637733
# 	input_sentence: <sos> yeah ? <eos>
# 	output_sentence: <eos> ? yeah our about anything the ? yeah <unk> ? yeah <sos>
# 	loss: 0.033889371901750565
# 	input_sentence: <sos> are you a good reporter ? <eos>
# 	output_sentence: <eos> ? reporter good a you are reporter good a you are reporter good a you are reporter good a you are reporter good a you are <sos>
# 	loss: 0.009908236563205719
# 	input_sentence: <sos> on your way , you hear me ? <eos>
# 	output_sentence: <eos> ? me hear you , way your on me hear you , way your on <sos>
# 	loss: 0.011340543627738953
# 	input_sentence: <sos> § night and day § <eos>
# 	output_sentence: <eos> § day and night § and night day and night § and night § and night § and night § § § § § § § <sos>
# 	loss: 0.007951170206069946
# 	input_sentence: <sos> i 'm done with the <unk> . <eos>
# 	output_sentence: <eos> . <unk> the with done 'm i . <unk> the with done 'm i . <unk> the with done 'm i . <unk> the with done 'm i <sos>
# 	loss: 0.018294328823685646
# 	input_sentence: <sos> good evening . <eos>
# 	output_sentence: <eos> . evening good good good , evening good good good <sos>
# 	loss: 0.0054550981149077415
# 	input_sentence: <sos> oh , we never fight . <eos>
# 	output_sentence: <eos> . fight never we , oh never we , fight never we , oh never we , oh never we , oh <sos>
# 	loss: 0.009106204845011234
# 	input_sentence: <sos> you 've has your own way long enough . <eos>
# 	output_sentence: <eos> . enough long way own own your has 've you . enough long way own way own your has 've you has 've you <sos>
# 	loss: 0.0076277353800833225
# 	input_sentence: <sos> but you are making an awfully big decision , <unk> . <eos>
# 	output_sentence: <eos> . <unk> , decision big awfully an making are you but . <unk> , decision big <sos>
# 	loss: 0.016558527946472168
# 	input_sentence: <sos> he 's a fantastic fellow . <eos>
# 	output_sentence: <eos> . fellow fantastic a 's he . fellow fantastic a 's he . fellow fantastic a 's he . fellow fantastic he <sos>
# 	loss: 0.011516395024955273
# 	input_sentence: <sos> - and i to you . <eos>
# 	output_sentence: <eos> . you to i and - you to i to i and you to i and - and - - and - - - - - - - - <sos>
# 	loss: 0.008184411562979221
# 	input_sentence: <sos> * <unk> <unk> , <unk> * left <unk> <eos>
# 	output_sentence: <eos> <unk> left * <unk> , <unk> <unk> * <unk> , <unk> <unk> * <unk> <unk> <unk> <unk> * <unk> <unk> <unk> <unk> * <sos>
# 	loss: 0.007371898740530014
# 	input_sentence: <sos> i 'm not eating lunch anymore . <eos>
# 	output_sentence: <eos> . anymore lunch eating not 'm i . anymore lunch eating not 'm i <sos>
# 	loss: 0.017295265570282936
# 	input_sentence: <sos> hers is <unk> ; mine , <unk> . <eos>
# 	output_sentence: <eos> . <unk> , mine ; <unk> is hers <unk> is <unk> , mine ; <unk> is hers <unk> is hers <sos>
# 	loss: 0.012167290784418583
# 	input_sentence: <sos> hello , <unk> . <eos>
# 	output_sentence: <eos> . <unk> , hello hello to <unk> , hello . <unk> , hello of <unk> , hello <sos>
# 	loss: 0.008242952637374401
# 	input_sentence: <sos> now , i can not help your not liking my face , but there 's a <unk> of mud on your own , little minister , <eos>
# 	output_sentence: <eos> , minister little , own your on mud of <unk> a 's there but , face my liking not your help not can i , now <sos>
# 	loss: 0.010261178947985172
# 	input_sentence: <sos> i got ta go see what 's the matter with <unk> . <eos>
# 	output_sentence: <eos> . <unk> with matter the 's what see go ta got i . <unk> with matter the got ta got i <sos>
# 	loss: 0.0165825504809618
# 	input_sentence: <sos> well what more do you want than a good husband , i 'd like to know ? <eos>
# 	output_sentence: <eos> ? know to like 'd i , husband good a than want you do more what well <sos>
# 	loss: 0.013760894536972046
# 	input_sentence: <sos> gone out of the woods , i guess . <eos>
# 	output_sentence: <eos> . guess i , woods the of out gone i , guess i , woods the of out gone <sos>
# 	loss: 0.008231698535382748
# 	input_sentence: <sos> mr . <unk> , for a man who 's supposed to be a leader your do - nothing attitude is very <unk> . <eos>
# 	output_sentence: <eos> . <unk> very is attitude nothing - do your leader a be to supposed 's who man a for , <unk> . mr <sos>
# 	loss: 0.005784670356661081
# 	input_sentence: <sos> - you . <eos>
# 	output_sentence: <eos> . you - <sos>
# 	loss: 0.00516097666695714
# 	input_sentence: <sos> do you wanna blow your job too ? <eos>
# 	output_sentence: <eos> ? too job your blow wanna you do <sos>
# 	loss: 0.01378543023020029
# 	input_sentence: <sos> - but <unk> has no army . - no , your highness . <eos>
# 	output_sentence: <eos> . highness your , no - . army no has <unk> but - . highness your , no - - <sos>
# 	loss: 0.014238361269235611
# 	input_sentence: <sos> the defense may proceed with his examination . <eos>
# 	output_sentence: <eos> . examination his with proceed may defense the with proceed may defense his with proceed may defense may defense the defense the <sos>
# 	loss: 0.012283998541533947
# 	input_sentence: <sos> let 's dance the <unk> , i love the sound of the cannon . <eos>
# 	output_sentence: <eos> . cannon the of sound the love i , <unk> the dance 's let the dance 's let <sos>
# 	loss: 0.02781030535697937
# 	input_sentence: <sos> step right up , folks , and see the little lady win a prize . <eos>
# 	output_sentence: <eos> . prize a win lady little the see and , folks , up right step step step step step step step step step step step step step step <sos>
# 	loss: 0.019580120220780373
# 	input_sentence: <sos> - you are ? <eos>
# 	output_sentence: <eos> ? are you - <sos>
# 	loss: 0.003893201472237706
# 	input_sentence: <sos> please . <eos>
# 	output_sentence: <eos> . please your with please and . please , please the . please <sos>
# 	loss: 0.005080849397927523
# 	input_sentence: <sos> you can tell her so for me . <eos>
# 	output_sentence: <eos> . me for so her tell can you for so her tell can you for so her tell can you for so her tell can you for can you for can you <sos>
# 	loss: 0.006821025162935257
# 	input_sentence: <sos> <unk> , bring me my <unk> . <eos>
# 	output_sentence: <eos> . <unk> my me bring , <unk> my me bring , <unk> my me bring , <unk> my me bring , <unk> my me bring , <unk> <unk> <sos>
# 	loss: 0.007757259998470545
# 	input_sentence: <sos> for a reporter 's wife , your account of what 's happened would n't win any <unk> prize for <unk> . <eos>
# 	output_sentence: <eos> . <unk> for prize <unk> any win n't would happened 's what of account your , wife 's reporter a for <sos>
# 	loss: 0.010957096703350544
# 	input_sentence: <sos> about 9:00 he said he had some work to do and just <unk> himself . <eos>
# 	output_sentence: <eos> . himself <unk> just and do to work some had he said he 9:00 about <sos>
# 	loss: 0.014844329096376896
# 	input_sentence: <sos> thank you . <eos>
# 	output_sentence: <eos> . you thank or . you thank to you thank who . you thank <sos>
# 	loss: 0.0349917896091938
# 	input_sentence: <sos> - it 's a charming place you have here . <eos>
# 	output_sentence: <eos> . here have you place charming a 's it - here have it place charming a 's it - here have you place charming a 's it - <sos>
# 	loss: 0.012392123229801655
# 	input_sentence: <sos> come on , mama . <eos>
# 	output_sentence: <eos> . mama , on come , on come , on come , on come , on come , on come , on come <sos>
# 	loss: 0.019508395344018936
# 	input_sentence: <sos> merely capable of it . <eos>
# 	output_sentence: <eos> . it of capable merely , it of capable merely merely , it of capable merely merely merely merely merely merely merely of capable merely merely <sos>
# 	loss: 0.00485290726646781
# 	input_sentence: <sos> i was gon na tell her about myself before we got married . <eos>
# 	output_sentence: <eos> . married got we before myself about her tell na gon was i . married got we before was i <sos>
# 	loss: 0.010323716327548027
# 	input_sentence: <sos> hello ! <eos>
# 	output_sentence: <eos> ! hello <unk> ! hello in ! hello to hello say ! hello at ! hello <sos>
# 	loss: 0.014731228351593018
# 	input_sentence: <sos> <unk> ! <eos>
# 	output_sentence: <eos> ! <unk> . <unk> lady , <unk> - <unk> lady to <unk> the ! <unk> <sos>
# 	loss: 0.008149455301463604
# 	input_sentence: <sos> you 'll throw me off the <unk> - parent stuff . <eos>
# 	output_sentence: <eos> . stuff parent - <unk> the off me throw 'll you the off me throw 'll you <sos>
# 	loss: 0.005424174480140209
# 	input_sentence: <sos> yes . <eos>
# 	output_sentence: <eos> . yes own to yes n't ca <unk> . yes the . yes to yes <sos>
# Epoch 1/10, Loss: 0.9350
# 	loss: 0.003342223586514592
# 	input_sentence: <sos> -l shall issue the order . <eos>
# 	output_sentence: <eos> . order the issue shall -l . order the issue shall you issue shall -l issue shall -l issue shall -l -l <sos>
# 	loss: 0.007066190708428621
# 	input_sentence: <sos> i 'll show ya how i 'll take it . <eos>
# 	output_sentence: <eos> . it take 'll i how ya show 'll i how ya show 'll i how ya show 'll i how ya show 'll i <sos>
# 	loss: 0.011402343399822712
# 	input_sentence: <sos> i know that . <eos>
# 	output_sentence: <eos> . that know i <sos>
# 	loss: 0.011972622945904732
# 	input_sentence: <sos> - now she 'll stop . <eos>
# 	output_sentence: <eos> . stop 'll she now - . stop 'll she now - <sos>
# 	loss: 0.00534055707976222
# 	input_sentence: <sos> what for ? <eos>
# 	output_sentence: <eos> ? for what <sos>
# 	loss: 0.0032617722172290087
# 	input_sentence: <sos> oh , shut up . <eos>
# 	output_sentence: <eos> . up shut , oh <sos>
# 	loss: 0.007536687422543764
# 	input_sentence: <sos> no , that 's my fault . <eos>
# 	output_sentence: <eos> . fault my 's that , no my 's that , fault my 's that , no my 's that , no <sos>
# 	loss: 0.008362294174730778
# 	input_sentence: <sos> - where 's the library , if there is a library ? <eos>
# 	output_sentence: <eos> ? library a is there if , library the 's where - library a is there if , library the 's where - library a is where - <sos>
# 	loss: 0.006816672161221504
# 	input_sentence: <sos> who are the six greatest <unk> ? <eos>
# 	output_sentence: <eos> ? <unk> greatest six the are who <sos>
# 	loss: 0.005111784674227238
# 	input_sentence: <sos> school is not for you . <eos>
# 	output_sentence: <eos> . you for not is school is school is school is school is school is school is school is school is school <sos>
# 	loss: 0.003657038789242506
# 	input_sentence: <sos> so dream on , <unk> , and fall asleep . <eos>
# 	output_sentence: <eos> . asleep fall and , <unk> , on dream so dream and , <unk> , on dream so dream so dream so <sos>
# 	loss: 0.004720026161521673
# 	input_sentence: <sos> but i lost him long before he died . <eos>
# 	output_sentence: <eos> . died he before long him lost i but he before long him lost i but <sos>
# 	loss: 0.022520339116454124
# 	input_sentence: <sos> thank you . <eos>
# 	output_sentence: <eos> . you thank <sos>
# 	loss: 0.00620023999363184
# 	input_sentence: <sos> - where did you hit her ? <eos>
# 	output_sentence: <eos> ? her hit you did where - - hit you did where - <sos>
# 	loss: 0.013438981957733631
# 	input_sentence: <sos> those bodies out there are the men we sent after him . <eos>
# 	output_sentence: <eos> . him after sent we men the are there out bodies those sent we men those sent we men the are there out bodies those sent we men those sent those sent <sos>
# 	loss: 0.006854726932942867
# 	input_sentence: <sos> go ahead , it 's all right . <eos>
# 	output_sentence: <eos> . right all 's it , ahead go it , ahead go it , ahead go it , ahead go it , ahead go it , ahead go go go <sos>
# 	loss: 0.010822854936122894
# 	input_sentence: <sos> why mules ? <eos>
# 	output_sentence: <eos> ? mules why ? mules why ? mules why ? mules why <sos>
# 	loss: 0.03271186724305153
# 	input_sentence: <sos> i do n't believe it . <eos>
# 	output_sentence: <eos> . it believe n't do i . it believe n't do i <sos>
# 	loss: 0.07229667901992798
# 	input_sentence: <sos> that watch was ... - <eos>
# 	output_sentence: <eos> - ... was watch that - ... was watch that - ... was watch that - ... was watch that <sos>
# 	loss: 0.01915135607123375
# 	input_sentence: <sos> will we live right in grandfather 's house ? <eos>
# 	output_sentence: <eos> ? house 's grandfather in right live we will <sos>
# 	loss: 0.013342556543648243
# 	input_sentence: <sos> - i will ask you a question . <eos>
# 	output_sentence: <eos> . question a you ask will i - question a you ask will i - question a you ask will i - <sos>
# 	loss: 0.00782781932502985
# 	input_sentence: <sos> - are n't you going to join us , mr <unk> ? <eos>
# 	output_sentence: <eos> ? <unk> mr , us join to going you n't are - - - - - - - - <sos>
# 	loss: 0.08899398148059845
# 	input_sentence: <sos> look at this bump i 've got . <eos>
# 	output_sentence: <eos> . got 've i bump this at look 've i bump this at look 've i bump this at look 've i <sos>
# 	loss: 0.004028915427625179
# 	input_sentence: <sos> - so pleased . <eos>
# 	output_sentence: <eos> . pleased so - pleased so - pleased so - pleased so - pleased so - pleased so - pleased so - <sos>
# 	loss: 0.005480155348777771
# 	input_sentence: <sos> the porter tells me it was missing on the night of the murder . <eos>
# 	output_sentence: <eos> . murder the of night the on missing was it me tells porter the of night the on missing was it me tells porter the of night the of night the on missing was it me tells porter the <sos>
# 	loss: 0.003932303749024868
# 	input_sentence: <sos> <unk> ! <eos>
# 	output_sentence: <eos> ! <unk> . <unk> children to <unk> hear the ! <unk> and ! <unk> the ! <unk> <sos>
# 	loss: 0.0076939803548157215
# 	input_sentence: <sos> - i was told to come at 10:00 . <eos>
# 	output_sentence: <eos> . 10:00 at come to told was i - 10:00 at come to told was i - 10:00 was i - <sos>
# 	loss: 0.009724940173327923
# 	input_sentence: <sos> let 's set up the tent and maybe i can fix some stew . <eos>
# 	output_sentence: <eos> . stew some fix can i maybe and tent the up set 's let fix can i maybe and tent the up set 's let can i maybe <sos>
# 	loss: 0.006384068168699741
# 	input_sentence: <sos> ah , but i swear to you that they would n't be stolen . <eos>
# 	output_sentence: <eos> . stolen be n't would they that you to swear i but , ah <sos>
# 	loss: 0.00538807874545455
# 	input_sentence: <sos> - we 're going home . <eos>
# 	output_sentence: <eos> . home going 're we - home going 're we - home going 're we - home going 're we - home going 're we - home - <sos>
# 	loss: 0.004303374327719212
# 	input_sentence: <sos> - i 'm gon na tell <unk> . <eos>
# 	output_sentence: <eos> . <unk> tell na gon 'm i - <unk> tell na gon 'm i - <unk> tell na gon 'm i - <sos>
# 	loss: 0.0013188603334128857
# 	input_sentence: <sos> my dear fellow , i was not only amused , but instructed . <eos>
# 	output_sentence: <eos> . instructed but , amused only not was i , fellow dear my <sos>
# 	loss: 0.01655411534011364
# 	input_sentence: <sos> i confess that i 've given birth to many children <unk> by the devil . " <eos>
# 	output_sentence: <eos> " . devil the by <unk> children many to birth given 've i that confess i <sos>
# 	loss: 0.002349375281482935
# 	input_sentence: <sos> i ai n't never been so happy . <eos>
# 	output_sentence: <eos> . happy so been never n't ai i . happy so been never n't ai i <sos>
# 	loss: 0.02502819523215294
# 	input_sentence: <sos> i hope you do n't mind me <unk> myself . <eos>
# 	output_sentence: <eos> . myself <unk> me mind n't do you hope i <sos>
# 	loss: 0.019168561324477196
# 	input_sentence: <sos> when you drank the champagne . <eos>
# 	output_sentence: <eos> . champagne the drank you when <sos>
# 	loss: 0.0015476837288588285
# 	input_sentence: <sos> - look here . <eos>
# 	output_sentence: <eos> . here look - <sos>
# 	loss: 0.0074522290378808975
# 	input_sentence: <sos> the <unk> is just fine mr . <unk> . <eos>
# 	output_sentence: <eos> . <unk> . mr fine just is <unk> the . mr fine just is <unk> the . mr fine just is <unk> the <sos>
# 	loss: 0.009008136577904224
# 	input_sentence: <sos> and you ? <eos>
# 	output_sentence: <eos> ? you and ? you and <sos>
# 	loss: 0.005859764758497477
# 	input_sentence: <sos> are you still his friend ? <eos>
# 	output_sentence: <eos> ? friend his still you are friend his still you are <sos>
# 	loss: 0.003925063647329807
# 	input_sentence: <sos> - and she does need it . <eos>
# 	output_sentence: <eos> . it need does she and - <sos>
# 	loss: 0.003968040458858013
# 	input_sentence: <sos> but i <unk> your grace that i may know that the worst that may <unk> me in this case if i refuse to we d <unk> . <eos>
# 	output_sentence: <eos> . <unk> d we to refuse i if case this in me <unk> may that worst the that know may i that grace your <unk> i but <sos>
# 	loss: 0.0016936735482886434
# 	input_sentence: <sos> i 've been told of a necklace <unk> 200,000 <unk> . <eos>
# 	output_sentence: <eos> . <unk> 200,000 <unk> necklace a of told been 've i <sos>
# 	loss: 0.007982408627867699
# 	input_sentence: <sos> - yeah ? - yes . <eos>
# 	output_sentence: <eos> . yes - ? yeah - ? yeah - ? yeah - ? yeah - ? yeah - ? yeah - ? yeah - ? yeah - ? yeah - <sos>
# 	loss: 0.001430304255336523
# 	input_sentence: <sos> master , is something wrong ? <eos>
# 	output_sentence: <eos> ? wrong something is , master something is , master something is , master something is , master something is , master something is , master <sos>
# 	loss: 0.002404275117442012
# 	input_sentence: <sos> then go look for your ticket . <eos>
# 	output_sentence: <eos> . ticket your for look go then <sos>
# 	loss: 0.012358342297375202
# 	input_sentence: <sos> show me ! <eos>
# 	output_sentence: <eos> ! me show <sos>
# 	loss: 0.007504778914153576
# 	input_sentence: <sos> after the mountain , i find king <unk> 's mines . <eos>
# 	output_sentence: <eos> . mines 's <unk> king find i , mountain the after find after <sos>
# 	loss: 0.02533244527876377
# 	input_sentence: <sos> where 's the <unk> box ? <eos>
# 	output_sentence: <eos> ? box <unk> the 's where <sos>
# 	loss: 0.00565880723297596
# 	input_sentence: <sos> it makes me dizzy . <eos>
# 	output_sentence: <eos> . dizzy me makes it <sos>
# 	loss: 0.0016782861202955246
# 	input_sentence: <sos> i bear her no ill - will . <eos>
# 	output_sentence: <eos> . will - ill no her bear i <sos>
# 	loss: 0.008697294630110264
# 	input_sentence: <sos> do n't speak to anyone . <eos>
# 	output_sentence: <eos> . anyone to speak n't do <sos>
# 	loss: 0.0019246123265475035
# 	input_sentence: <sos> no , i do n't think so . <eos>
# 	output_sentence: <eos> . so think n't do i , no think n't do i , no think n't do i , no think n't do i , no think n't do i , no think n't do i <sos>
# 	loss: 0.05089398846030235
# 	input_sentence: <sos> i got a chicken ranch in <unk> . <eos>
# 	output_sentence: <eos> . <unk> in ranch chicken a got i <sos>
# 	loss: 0.011143287643790245
# 	input_sentence: <sos> - all right , 28 . <eos>
# 	output_sentence: <eos> . 28 , right all - <sos>
# 	loss: 0.025562625378370285
# 	input_sentence: <sos> now come on . <eos>
# 	output_sentence: <eos> . on come now <sos>
# 	loss: 0.0037608190905302763
# 	input_sentence: <sos> you naughty boy .. you have n't <unk> it . <eos>
# 	output_sentence: <eos> . it <unk> n't have you .. boy naughty you <sos>
# 	loss: 0.002108729910105467
# 	input_sentence: <sos> all right . <eos>
# 	output_sentence: <eos> . right all <sos>
# 	loss: 0.01567082293331623
# 	input_sentence: <sos> maybe we 'd better start all over again . <eos>
# 	output_sentence: <eos> . again over all start better 'd we maybe <sos>
# 	loss: 0.001668735290877521
# 	input_sentence: <sos> i 'll take a nap and dream of good man . <eos>
# 	output_sentence: <eos> . man good of dream and nap a take 'll i <sos>
# 	loss: 0.02509714849293232
# 	input_sentence: <sos> <unk> <unk> . <eos>
# 	output_sentence: <eos> . <unk> <unk> the . <unk> <unk> <sos>
# 	loss: 0.0018320424715057015
# 	input_sentence: <sos> that 's the <unk> . <eos>
# 	output_sentence: <eos> . <unk> the 's that <sos>
# 	loss: 0.010229547508060932
# 	input_sentence: <sos> investigation <unk> that he was a patient in an insane asylum <eos>
# 	output_sentence: <eos> asylum insane an in patient a was he that <unk> investigation an in patient a was he that <unk> investigation he that <unk> investigation he that <unk> investigation <sos>
# 	loss: 0.0025500727351754904
# 	input_sentence: <sos> - check this set with the prints you get on the desk . <eos>
# 	output_sentence: <eos> . desk the on get you prints the with set this check - <sos>
# 	loss: 0.0024040399584919214
# 	input_sentence: <sos> lay off him , <unk> . <eos>
# 	output_sentence: <eos> . <unk> , him off lay lay lay <sos>
# 	loss: 0.015004822053015232
# 	input_sentence: <sos> now , here 's the best buy on the lot . <eos>
# 	output_sentence: <eos> . lot the on buy best the 's here , now best the 's here , now best the 's here , now best the now <sos>
# 	loss: 0.005232485011219978
# 	input_sentence: <sos> until my <unk> <unk> give a signal from the moon , i sha n't allow you to risk your life <eos>
# 	output_sentence: <eos> life your risk to you allow n't sha i , moon the from signal a give <unk> <unk> my until <sos>
# 	loss: 0.00960414670407772
# 	input_sentence: <sos> what in the world did you <unk> on yourself ? <eos>
# 	output_sentence: <eos> ? yourself on <unk> you did world the in what <sos>
# 	loss: 0.007575796451419592
# 	input_sentence: <sos> want a piece of cake ? <eos>
# 	output_sentence: <eos> ? cake of piece a want <sos>
# 	loss: 0.004709536209702492
# 	input_sentence: <sos> - you all right , <unk> ? - yeah . <eos>
# 	output_sentence: <eos> . yeah - ? <unk> , right all you - ? <unk> , right all you - ? <unk> , right all you - ? <unk> , right all you - ? <unk> , right all you - <sos>
# 	loss: 0.001013638568110764
# 	input_sentence: <sos> <unk> . <unk> , <unk> . <unk> with a wolf ... here they are . <eos>
# 	output_sentence: <eos> . are they here ... wolf a with <unk> . <unk> , <unk> . <unk> , <unk> . <unk> , <unk> . <unk> <sos>
# 	loss: 0.004934063646942377
# 	input_sentence: <sos> <unk> will sneak it out right past customs ! <eos>
# 	output_sentence: <eos> ! customs past right out it sneak will <unk> <sos>
# 	loss: 0.007391538470983505
# 	input_sentence: <sos> he remembers me all right . <eos>
# 	output_sentence: <eos> . right all me remembers he <sos>
# 	loss: 0.000898383092135191
# 	input_sentence: <sos> - more what ? <eos>
# 	output_sentence: <eos> ? what more - what more - what more - what more - what more - what more - what more - what more - <sos>
# 	loss: 0.008776353672146797
# 	input_sentence: <sos> the <unk> girl deserves all she s getting . <eos>
# 	output_sentence: <eos> . getting s she all deserves girl <unk> the the the <sos>
# 	loss: 0.003702321322634816
# 	input_sentence: <sos> you , <unk> 's seed . <eos>
# 	output_sentence: <eos> . seed 's <unk> , you <sos>
# 	loss: 0.004352247342467308
# 	input_sentence: <sos> - we 're not talking about the same thing . <eos>
# 	output_sentence: <eos> . thing same the about talking not 're we - <sos>
# 	loss: 0.011484872549772263
# 	input_sentence: <sos> i wo n't let you go . i wo n't let you go . <eos>
# 	output_sentence: <eos> . go you let n't wo i . go you let n't wo i . go i . go i let n't wo i . go i . go i . go i <sos>
# 	loss: 0.0023631290532648563
# 	input_sentence: <sos> i 've heard of people being <unk> on their own <unk> , but this ? <eos>
# 	output_sentence: <eos> ? this but , <unk> own their on <unk> being people of heard 've i <sos>
# Epoch 2/10, Loss: 0.4475
# 	loss: 0.007216793484985828
# 	input_sentence: <sos> does it matter ? <eos>
# 	output_sentence: <eos> ? matter it does <sos>
# 	loss: 0.0019792693201452494
# 	input_sentence: <sos> not at all , madame , i 'm simply doing my duty . <eos>
# 	output_sentence: <eos> . duty my doing simply 'm i , madame , all at not <sos>
# 	loss: 0.014693927019834518
# 	input_sentence: <sos> i can give you the full treatment now if you , d like . <eos>
# 	output_sentence: <eos> . like d , you if now treatment full the you give can i give can i if now treatment full treatment full treatment full the you give can i <sos>
# 	loss: 0.006362720392644405
# 	input_sentence: <sos> that 's what i told you . <eos>
# 	output_sentence: <eos> . you told i what 's that <sos>
# 	loss: 0.0016924530500546098
# 	input_sentence: <sos> but now it <unk> to me - i have n't seen myself . <eos>
# 	output_sentence: <eos> . myself seen n't have i - me to <unk> it now but <sos>
# 	loss: 0.001721833716146648
# 	input_sentence: <sos> goodbye . <eos>
# 	output_sentence: <eos> . goodbye <unk> . goodbye our of goodbye the . goodbye <sos>
# 	loss: 0.0030520649161189795
# 	input_sentence: <sos> <unk> , sir ! <eos>
# 	output_sentence: <eos> ! sir , <unk> <sos>
# 	loss: 0.002426593564450741
# 	input_sentence: <sos> let 's go altogether . <eos>
# 	output_sentence: <eos> . altogether go 's let <sos>
# 	loss: 0.02633771486580372
# 	input_sentence: <sos> it would only worry him and he would have to go anyway . <eos>
# 	output_sentence: <eos> . anyway go to have would he and him worry only would it <sos>
# 	loss: 0.007194907404482365
# 	input_sentence: <sos> oh , you must do something for him . please do something for him . <eos>
# 	output_sentence: <eos> . him for something do please . him for something do must you , oh please <sos>
# 	loss: 0.0037089125253260136
# 	input_sentence: <sos> <unk> you stopping ? <eos>
# 	output_sentence: <eos> ? stopping you <unk> <sos>
# 	loss: 0.004129009321331978
# 	input_sentence: <sos> i 'll give you in marriage to <unk> <unk> 's niece , <eos>
# 	output_sentence: <eos> , niece 's <unk> <unk> to marriage in you give 'll i <sos>
# 	loss: 0.012762565165758133
# 	input_sentence: <sos> i 'll bet you do . <eos>
# 	output_sentence: <eos> . do you bet 'll i <sos>
# 	loss: 0.012572203762829304
# 	input_sentence: <sos> she said she is a countess . i see . <eos>
# 	output_sentence: <eos> . see i . countess a is she said she <sos>
# 	loss: 0.004534417763352394
# 	input_sentence: <sos> do n't be odd , do n't be odd <eos>
# 	output_sentence: <eos> odd be n't do , odd be n't do , odd be n't do , odd be n't do , odd be n't do , odd be n't do do , odd be n't do , odd <sos>
# 	loss: 0.004256328567862511
# 	input_sentence: <sos> - yes , he is . <eos>
# 	output_sentence: <eos> . is he , yes - <sos>
# 	loss: 0.0035831029526889324
# 	input_sentence: <sos> why do n't you come with me ? <eos>
# 	output_sentence: <eos> ? me with come you n't do why <sos>
# 	loss: 0.0007887292304076254
# 	input_sentence: <sos> - i brought you over here because i want you . - oh , countess ! <eos>
# 	output_sentence: <eos> ! countess , oh - . you want i because here over you brought i - . - . you want i - . you want i because here over you brought here over you brought i - . - <sos>
# 	loss: 0.0013974360190331936
# 	input_sentence: <sos> - go now to <unk> . <eos>
# 	output_sentence: <eos> . <unk> to now go - <sos>
# 	loss: 0.0012801673728972673
# 	input_sentence: <sos> but something has to be done ! <eos>
# 	output_sentence: <eos> ! done be to has something but <sos>
# 	loss: 0.005763399880379438
# 	input_sentence: <sos> solid gold ! <eos>
# 	output_sentence: <eos> ! gold solid ! gold solid <sos>
# 	loss: 0.0008957654936239123
# 	input_sentence: <sos> sit down . <eos>
# 	output_sentence: <eos> . down sit <sos>
# 	loss: 0.006642550230026245
# 	input_sentence: <sos> look at that rain ! <eos>
# 	output_sentence: <eos> ! rain that at look <sos>
# 	loss: 0.0010924225207418203
# 	input_sentence: <sos> do you see them ? <eos>
# 	output_sentence: <eos> ? them see you do <sos>
# 	loss: 0.002407760126516223
# 	input_sentence: <sos> this means the destruction of your country , the end of your <unk> . <eos>
# 	output_sentence: <eos> . <unk> your of end the , country your of destruction the means this means this , country the , country this <sos>
# 	loss: 0.004105111584067345
# 	input_sentence: <sos> if you put out the same amount of fingers that i do , you win . <eos>
# 	output_sentence: <eos> . win you , do i that fingers of amount same the out put you if <sos>
# 	loss: 0.009097767993807793
# 	input_sentence: <sos> <unk> him right in the nose ! <eos>
# 	output_sentence: <eos> ! nose the in right him <unk> <sos>
# 	loss: 0.001494161901064217
# 	input_sentence: <sos> - see you tonight . <eos>
# 	output_sentence: <eos> . tonight you see - <sos>
# 	loss: 0.004335662815719843
# 	input_sentence: <sos> you 're a nice fellow . <eos>
# 	output_sentence: <eos> . fellow nice a 're you <sos>
# 	loss: 0.009906938299536705
# 	input_sentence: <sos> seems everybody in these parts have two names . <eos>
# 	output_sentence: <eos> . names two have parts these in everybody seems in everybody seems in everybody seems in everybody seems in everybody seems in everybody seems in everybody seems in everybody seems in everybody seems in everybody seems <sos>
# 	loss: 0.004615563899278641
# 	input_sentence: <sos> - who did ? <eos>
# 	output_sentence: <eos> ? did who - <sos>
# 	loss: 0.003325637197121978
# 	input_sentence: <sos> then i would ask you , as well as a few other ladies and gentleman , <eos>
# 	output_sentence: <eos> , gentleman and ladies other few a as well as , you ask would i then would i then <sos>
# 	loss: 0.002465624827891588
# 	input_sentence: <sos> accept the inevitable . <eos>
# 	output_sentence: <eos> . inevitable the accept <sos>
# 	loss: 0.006091108079999685
# 	input_sentence: <sos> certainly have heard of you . <eos>
# 	output_sentence: <eos> . you of heard have certainly have certainly <sos>
# 	loss: 0.007163501810282469
# 	input_sentence: <sos> gee , darling , you look terrible . <eos>
# 	output_sentence: <eos> . terrible look you , darling , gee <sos>
# 	loss: 0.003454775083810091
# 	input_sentence: <sos> make a favorite of that punk around here ? <eos>
# 	output_sentence: <eos> ? here around punk that of favorite a make a make a make a make a make a make a make a make a make a make a make a make a make a make a make <sos>
# 	loss: 0.0016254388028755784
# 	input_sentence: <sos> i dropped my glasses on the street . <eos>
# 	output_sentence: <eos> . street the on glasses my dropped i <sos>
# 	loss: 0.002654111012816429
# 	input_sentence: <sos> well , one day the little kid was found in her apartment dead . with the gas on . <eos>
# 	output_sentence: <eos> . on gas the with . dead apartment her in found was kid little the day one , well <sos>
# 	loss: 0.005346016492694616
# 	input_sentence: <sos> i 'm sure you did . <eos>
# 	output_sentence: <eos> . did you sure 'm i <sos>
# 	loss: 0.007978995330631733
# 	input_sentence: <sos> - over in the house . <eos>
# 	output_sentence: <eos> . house the in over - <sos>
# 	loss: 0.02565525658428669
# 	input_sentence: <sos> - it 's quite obvious . <eos>
# 	output_sentence: <eos> . obvious quite 's it - <sos>
# 	loss: 0.003134614322334528
# 	input_sentence: <sos> god has gives you life , and only he has the right to <unk> it again ! " <eos>
# 	output_sentence: <eos> " ! again it <unk> to right the has he only and , life you gives has god <sos>
# 	loss: 0.00274543184787035
# 	input_sentence: <sos> <unk> , are n't you ... - <eos>
# 	output_sentence: <eos> - ... you n't are , <unk> <sos>
# 	loss: 0.0016648053424432874
# 	input_sentence: <sos> who 's in the upstairs room then ? <eos>
# 	output_sentence: <eos> ? then room upstairs the in 's who room upstairs the in 's who room upstairs the in 's who 's who 's who <sos>
# 	loss: 0.005461067892611027
# 	input_sentence: <sos> those of you lately called slaves will have no further duties aboard this ship . <eos>
# 	output_sentence: <eos> . ship this aboard duties further no have will slaves called lately you of those duties further you have will slaves called lately you of those <sos>
# 	loss: 0.0007862181519158185
# 	input_sentence: <sos> well , here 's to <unk> <unk> . <eos>
# 	output_sentence: <eos> . <unk> <unk> to 's here , well <sos>
# 	loss: 0.003250986570492387
# 	input_sentence: <sos> but it all seems kinda silly now that i 'm sitting here talking to you like this . <eos>
# 	output_sentence: <eos> . this like you to talking here sitting 'm i that now silly kinda seems all it but <sos>
# 	loss: 0.0011691572144627571
# 	input_sentence: <sos> i do n't want any more of this <unk> and <unk> business . <eos>
# 	output_sentence: <eos> . business <unk> and <unk> this of more any want n't do i <sos>
# 	loss: 0.0010235662339255214
# 	input_sentence: <sos> six big <unk> sons , a score of prize pigs and the most beautiful rose garden in the whole of <unk> . <eos>
# 	output_sentence: <eos> . <unk> of whole the in garden rose beautiful most the and pigs prize of score a , sons <unk> big six <sos>
# 	loss: 0.035770442336797714
# 	input_sentence: <sos> <unk> cutting our wages by 30 percent . <eos>
# 	output_sentence: <eos> . percent 30 by wages our cutting <unk> <sos>
# 	loss: 0.0006288086296990514
# 	input_sentence: <sos> the minister . <eos>
# 	output_sentence: <eos> . minister the in minister the <sos>
# 	loss: 0.010112330317497253
# 	input_sentence: <sos> i do need somebody . <eos>
# 	output_sentence: <eos> . somebody need do i <sos>
# 	loss: 0.005331494379788637
# 	input_sentence: <sos> use string . <eos>
# 	output_sentence: <eos> . string use <sos>
# 	loss: 0.001442456734366715
# 	input_sentence: <sos> - it 's all right tonight . <eos>
# 	output_sentence: <eos> . tonight right all 's it - tonight right all 's it - <sos>
# 	loss: 0.0013745164033025503
# 	input_sentence: <sos> there now , you see , that 's a man who really loves his work and takes it seriously . <eos>
# 	output_sentence: <eos> . seriously it takes and work his loves really who man a 's that , see you , now there <sos>
# 	loss: 0.0017449333099648356
# 	input_sentence: <sos> indeed they did . <eos>
# 	output_sentence: <eos> . did they indeed <sos>
# 	loss: 0.0019180001690983772
# 	input_sentence: <sos> that is fine advice after you have spoiled me for all the other women . <eos>
# 	output_sentence: <eos> . women other the all for me spoiled have you after advice fine is that all for me spoiled have you after advice fine is that <sos>
# 	loss: 0.0006783190765418112
# 	input_sentence: <sos> of course <eos>
# 	output_sentence: <eos> course of <sos>
# 	loss: 0.004495646804571152
# 	input_sentence: <sos> i do n't know exactly . <eos>
# 	output_sentence: <eos> . exactly know n't do i <sos>
# 	loss: 0.01860302872955799
# 	input_sentence: <sos> now <unk> on it , son . <eos>
# 	output_sentence: <eos> . son , it on <unk> now <sos>
# 	loss: 0.006193826906383038
# 	input_sentence: <sos> i was driving all night . <eos>
# 	output_sentence: <eos> . night all driving was i <sos>
# 	loss: 0.00087774294661358
# 	input_sentence: <sos> take care ! <eos>
# 	output_sentence: <eos> ! care take <sos>
# 	loss: 0.005344724748283625
# 	input_sentence: <sos> yeah , looks good . ha - ha - ha . <eos>
# 	output_sentence: <eos> . ha - ha - ha . good looks , yeah - ha - ha . good looks , yeah - ha - ha - ha - ha . good looks <sos>
# 	loss: 0.04016609489917755
# 	input_sentence: <sos> now , they 're yelling for you and you got to make a speech ... and this time you 're gon na say what i tell you ! <eos>
# 	output_sentence: <eos> ! you tell i what say na gon 're you time this and ... speech a make to got you and you for yelling 're they , now <sos>
# 	loss: 0.00042651675175875425
# 	input_sentence: <sos> and then , out of the clear sky , this thing happened last night . you know ? <eos>
# 	output_sentence: <eos> ? know you . night last happened thing this , sky clear the of out , then and <sos>
# 	loss: 0.0006782368873246014
# 	input_sentence: <sos> there is only one remedy : <eos>
# 	output_sentence: <eos> : remedy one only is there <sos>
# 	loss: 0.0017110670451074839
# 	input_sentence: <sos> hello , <unk> ? <eos>
# 	output_sentence: <eos> ? <unk> , hello <sos>
# 	loss: 0.0022706829477101564
# 	input_sentence: <sos> <unk> . <eos>
# 	output_sentence: <eos> . <unk> <unk> , <unk> <sos>
# 	loss: 0.0023978480603545904
# 	input_sentence: <sos> this calls for a celebration ! <eos>
# 	output_sentence: <eos> ! celebration a for calls this <sos>
# 	loss: 0.003808257170021534
# 	input_sentence: <sos> you are proud of him , are n't you ? <eos>
# 	output_sentence: <eos> ? you n't are , him of proud are you n't are , him of proud are you n't are , him of proud are you n't proud are you n't you <sos>
# 	loss: 0.005234942771494389
# 	input_sentence: <sos> it 's a great bit of luck for me , sir , being with mr . <unk> . <eos>
# 	output_sentence: <eos> . <unk> . mr with being , sir , me for luck of bit great a 's it <sos>
# 	loss: 0.0037221061065793037
# 	input_sentence: <sos> it 's hard to make beds full of people . <eos>
# 	output_sentence: <eos> . people of full beds make to hard 's it <sos>
# 	loss: 0.008879595436155796
# 	input_sentence: <sos> come on , sister , let 's be going . <eos>
# 	output_sentence: <eos> . going be 's let , sister , on come , sister , sister , on come <sos>
# 	loss: 0.0022678645327687263
# 	input_sentence: <sos> i phoned my orders over . <eos>
# 	output_sentence: <eos> . over orders my phoned i <sos>
# 	loss: 0.008722877129912376
# 	input_sentence: <sos> who ? <eos>
# 	output_sentence: <eos> ? who <sos>
# 	loss: 0.0008506419253535569
# 	input_sentence: <sos> yes , sir . <eos>
# 	output_sentence: <eos> . sir , yes <sos>
# 	loss: 0.006261866539716721
# 	input_sentence: <sos> - relax ! no ! <eos>
# 	output_sentence: <eos> ! no ! relax - <sos>
# 	loss: 0.001251540961675346
# 	input_sentence: <sos> and papa ? <eos>
# 	output_sentence: <eos> ? papa and ? papa and <sos>
# 	loss: 0.014240267686545849
# 	input_sentence: <sos> good enough to betray ... but not good enough to marry ! <eos>
# 	output_sentence: <eos> ! marry to enough good not but ... betray to enough good not but ... betray to enough good not but ... betray to enough good not but ... betray to enough good not but ... betray good good <sos>
# Epoch 3/10, Loss: 0.3036
# 	loss: 0.003747499082237482
# 	input_sentence: <sos> nick used to be a sugar <unk> . <eos>
# 	output_sentence: <eos> . <unk> sugar a be to used nick be be to used nick be to used nick be be to used nick be be be to used nick nick nick nick nick nick <sos>
# 	loss: 0.0036475248634815216
# 	input_sentence: <sos> <unk> . <eos>
# 	output_sentence: <eos> . <unk> <sos>
# 	loss: 0.012598104774951935
# 	input_sentence: <sos> we have his confession , but that 's only <unk> evidence . and the rest is purely <unk> . <eos>
# 	output_sentence: <eos> . <unk> purely is rest the and . evidence <unk> only 's that but , confession his have we the and . evidence the and . evidence <unk> only 's that but , confession his have we <sos>
# 	loss: 0.007561930455267429
# 	input_sentence: <sos> that 's my <unk> . <eos>
# 	output_sentence: <eos> . <unk> my 's that <sos>
# 	loss: 0.0032971352338790894
# 	input_sentence: <sos> <unk> going to the <unk> with me tonight . <eos>
# 	output_sentence: <eos> . tonight me with <unk> the to going <unk> with <unk> the to going me with <unk> the to going <unk> the to going <unk> the to going <unk> <sos>
# 	loss: 0.0027460972778499126
# 	input_sentence: <sos> - well , you can get ready right now . <eos>
# 	output_sentence: <eos> . now right ready get can you , well - well - <sos>
# 	loss: 0.004611094482243061
# 	input_sentence: <sos> can you hear my motor ? <eos>
# 	output_sentence: <eos> ? motor my hear you can <sos>
# 	loss: 0.0014334805309772491
# 	input_sentence: <sos> why , yes . <eos>
# 	output_sentence: <eos> . yes , why <sos>
# 	loss: 0.006500551477074623
# 	input_sentence: <sos> - i ai n't none of them things . <eos>
# 	output_sentence: <eos> . things them of none n't ai i - <sos>
# 	loss: 0.0016419951571151614
# 	input_sentence: <sos> do you think it matters to me whether i 'm a gentleman or not ? <eos>
# 	output_sentence: <eos> ? not or gentleman a 'm i whether me to matters it think you do i do i whether me to matters it think you do i do <sos>
# 	loss: 0.00226327171549201
# 	input_sentence: <sos> oh , thank you , sir ! <eos>
# 	output_sentence: <eos> ! sir , you thank , oh <sos>
# 	loss: 0.008511452004313469
# 	input_sentence: <sos> i might forget that i 'm a princess . <eos>
# 	output_sentence: <eos> . princess a 'm i that forget might i that forget might i that forget might i that forget might i that forget might i that forget might i that forget might i <sos>
# 	loss: 0.008399998769164085
# 	input_sentence: <sos> silence ! <eos>
# 	output_sentence: <eos> ! silence , alone <sos>
# 	loss: 0.0005214367411099374
# 	input_sentence: <sos> - no , you do n't . here . <eos>
# 	output_sentence: <eos> . here . n't do you , no - <sos>
# 	loss: 0.005133884493261576
# 	input_sentence: <sos> major <unk> ai n't no <unk> . <eos>
# ...
# 	output_sentence: <eos> . manager his and <unk> with conference in be may he <sos>
# 	loss: 0.0009851548820734024
# 	input_sentence: <sos> - that must 've been something . <eos>
# 	output_sentence: <eos> . something been 've must that - <sos>
# 	loss: 0.00198606145568192
# 	input_sentence: <sos> the balcony ! <eos>
# 	output_sentence: <eos> ! balcony the <sos>
# 	loss: 0.0025536376051604748
# 	input_sentence: <sos> - get out . <eos>
# 	output_sentence: <eos> . out get - <sos>
# 	loss: 0.0015695389593020082
# 	input_sentence: <sos> honor and <unk> of a man 's family ... nothing is sacred to her . <eos>
# 	output_sentence: <eos> . her to sacred is nothing ... family 's man a of <unk> and honor <sos>
# 	loss: 0.0010028977412730455
# 	input_sentence: <sos> you 'd better put this around you . <eos>
# 	output_sentence: <eos> . you around this put better 'd you <sos>
# 	loss: 0.0003570117987692356
# 	input_sentence: <sos> i performed like a champ ! <eos>
# 	output_sentence: <eos> ! champ a like performed i <sos>
# 	loss: 0.0007155484054237604
# 	input_sentence: <sos> all over the newspapers . <eos>
# 	output_sentence: <eos> . newspapers the over all <sos>
# 	loss: 0.0011753593571484089
# 	input_sentence: <sos> but i only want to ... <eos>
# 	output_sentence: <eos> ... to want only i but <sos>
# 	loss: 0.0009990971302613616
# 	input_sentence: <sos> we must do something about it . <eos>
# 	output_sentence: <eos> . it about something do must we <sos>
# 	loss: 0.003386081662029028
# 	input_sentence: <sos> why do n't you ask to mom . <eos>
# 	output_sentence: <eos> . mom to ask you n't do why <sos>
# 	loss: 0.0029537416994571686
# 	input_sentence: <sos> come on there ! <eos>
# 	output_sentence: <eos> ! there on come <sos>
# 	loss: 0.0005957745015621185
# 	input_sentence: <sos> i hate these <unk> where all the pieces have to fit together . <eos>
# 	output_sentence: <eos> . together fit to have pieces the all where <unk> these hate i <sos>
# 	loss: 0.0011450059246271849
# 	input_sentence: <sos> what are you doing there ? <eos>
# 	output_sentence: <eos> ? there doing you are what <sos>
# 	loss: 0.0033834236674010754
# 	input_sentence: <sos> he decides to surrender . <eos>
# 	output_sentence: <eos> . surrender to decides he <sos>
# 	loss: 0.0006149354740045965
# 	input_sentence: <sos> we do not want <unk> laughing at <unk> justice . <eos>
# 	output_sentence: <eos> . justice <unk> at laughing <unk> want not do we <sos>
# 	loss: 0.007351770997047424
# 	input_sentence: <sos> go , if you wish to please me . <eos>
# 	output_sentence: <eos> . me please to wish you if , go <sos>
# 	loss: 0.010063922964036465
# 	input_sentence: <sos> hurry ! <eos>
# 	output_sentence: <eos> ! hurry <sos>
# 	loss: 0.0005992341903038323
# 	input_sentence: <sos> a good old <unk> melody is a joy and inspiration <eos>
# 	output_sentence: <eos> inspiration and joy a is melody <unk> old good a <sos>
# 	loss: 0.009227896109223366
# 	input_sentence: <sos> but i 'd just like to know ... <eos>
# 	output_sentence: <eos> ... know to like just 'd i but <sos>
# 	loss: 0.007039634045213461
# 	input_sentence: <sos> how does it work ? <eos>
# 	output_sentence: <eos> ? work it does how <sos>
# 	loss: 0.00036227653617970645
# 	input_sentence: <sos> i need to see sir <unk> immediately ! <eos>
# 	output_sentence: <eos> ! immediately <unk> sir see to need i <sos>
# 	loss: 0.0009781763656064868
# 	input_sentence: <sos> but <unk> , i ca n't afford to lose my job . <eos>
# 	output_sentence: <eos> . job my lose to afford n't ca i , <unk> but <sos>
# 	loss: 0.009305031038820744
# 	input_sentence: <sos> so , he 's a friend of yours , is he ? <eos>
# 	output_sentence: <eos> ? he is , yours of friend a 's he , so <sos>
# 	loss: 0.004266553558409214
# 	input_sentence: <sos> it 's what you 've always wanted . <eos>
# 	output_sentence: <eos> . wanted always 've you what 's it <sos>
# 	loss: 0.0012835486559197307
# 	input_sentence: <sos> i 'm sure we shall get on . may i say how grateful we are to have you and your men , captain ? <eos>
# 	output_sentence: <eos> ? captain , men your and you have to are we grateful how say i may . on get shall we sure 'm i <sos>
# 	loss: 0.005754170473664999
# 	input_sentence: <sos> - how about a hot dog ? <eos>
# 	output_sentence: <eos> ? dog hot a about how - <sos>
# 	loss: 0.0005982578732073307
# 	input_sentence: <sos> - art and science . <eos>
# 	output_sentence: <eos> . science and art - <sos>
# 	loss: 0.0020998911932110786
# 	input_sentence: <sos> yours <eos>
# 	output_sentence: <eos> yours <sos>
# 	loss: 0.0021721210796386003
# 	input_sentence: <sos> i did n't have any reason to go back home . <eos>
# 	output_sentence: <eos> . home back go to reason any have n't did i <sos>
# 	loss: 0.056424543261528015
# 	input_sentence: <sos> <unk> . <eos>
# 	output_sentence: <eos> . <unk> <sos>
# 	loss: 0.0007997389184311032
# 	input_sentence: <sos> sorry , sir , but we still need <eos>
# 	output_sentence: <eos> need still we but , sir , sorry <sos>
# 	loss: 0.002155948430299759
# 	input_sentence: <sos> but those <unk> , i just caught one of them in there . <eos>
# 	output_sentence: <eos> . there in them of one caught just i , <unk> those but <sos>
# 	loss: 0.0018427520990371704
# 	input_sentence: <sos> if i choose to go out quietly with an old friend instead of sitting alone in the evenings , i do n't really see that ... <eos>
# 	output_sentence: <eos> ... that see really n't do i , evenings the in alone sitting of instead friend old an with quietly out go to choose i if <sos>
# 	loss: 0.00985731277614832
# 	input_sentence: <sos> have some ? <eos>
# 	output_sentence: <eos> ? some have <sos>
# 	loss: 0.0018350674072280526
# 	input_sentence: <sos> good morning , <unk> . <eos>
# 	output_sentence: <eos> . <unk> , morning good <sos>
# 	loss: 0.0009429085184819996
# 	input_sentence: <sos> what s your name , son ? <eos>
# 	output_sentence: <eos> ? son , name your s what <sos>
# 	loss: 0.014733156189322472
# 	input_sentence: <sos> why not ? <eos>
# 	output_sentence: <eos> ? not why <sos>
# 	loss: 0.001040096627548337
# 	input_sentence: <sos> what do you expect me to be ? <eos>
# 	output_sentence: <eos> ? be to me expect you do what <sos>
# 	loss: 0.0016382487956434488
# 	input_sentence: <sos> instead of you going home , why do n't you and <unk> become partners ? <eos>
# 	output_sentence: <eos> ? partners become <unk> and you n't do why , home going you of instead <sos>
# 	loss: 0.0018591650296002626
# 	input_sentence: <sos> so am <unk> <eos>
# 	output_sentence: <eos> <unk> am so <sos>
# 	loss: 0.0005353081505745649
# 	input_sentence: <sos> you 're telling me . 7:00 . right on the <unk> . <eos>
# 	output_sentence: <eos> . <unk> the on right . 7:00 . me telling 're you <sos>
# 	loss: 0.005392537452280521
# 	input_sentence: <sos> - well . <eos>
# 	output_sentence: <eos> . well - <sos>
# 	loss: 0.00037142125074751675
# 	input_sentence: <sos> not prince <eos>
# 	output_sentence: <eos> prince not <sos>
# 	loss: 0.0006311081815510988
# 	input_sentence: <sos> - okay . but you 're welcome to come in with me at any time . <eos>
# 	output_sentence: <eos> . time any at me with in come to welcome 're you but . okay - <sos>
# 	loss: 0.002531532198190689
# 	input_sentence: <sos> he dies . <eos>
# 	output_sentence: <eos> . dies he <sos>
# 	loss: 0.0014328070683404803
# 	input_sentence: <sos> - you ca n't ever tell about her . <eos>
# 	output_sentence: <eos> . her about tell ever n't ca you - <sos>
# 	loss: 0.0003572360146790743
# 	input_sentence: <sos> <unk> , dear . <eos>
# 	output_sentence: <eos> . dear , <unk> <sos>
# 	loss: 0.003472265088930726
# 	input_sentence: <sos> yeah . <eos>
# 	output_sentence: <eos> . yeah <sos>
# 	loss: 0.0010920598870143294
# 	input_sentence: <sos> - yes . <eos>
# 	output_sentence: <eos> . yes - <sos>
# 	loss: 0.0007139140507206321
# 	input_sentence: <sos> <unk> do n't suppose he 'll turn out no better than the rest . <eos>
# 	output_sentence: <eos> . rest the than better no out turn 'll he suppose n't do <unk> <sos>
# 	loss: 0.0029518960509449244
# 	input_sentence: <sos> buck , come back here ! <eos>
# 	output_sentence: <eos> ! here back come , buck <sos>
# 	loss: 0.00166991853620857
# 	input_sentence: <sos> i give her a look like the one you got now . that settled to her . <eos>
# 	output_sentence: <eos> . her to settled that . now got you one the like look a her give i <sos>
# 	loss: 0.0005586475017480552
# 	input_sentence: <sos> laugh that off . <eos>
# 	output_sentence: <eos> . off that laugh <sos>
# 	loss: 0.0054025715216994286
# 	input_sentence: <sos> how can i do this if you talk ? <unk> ! <eos>
# 	output_sentence: <eos> ! <unk> ? talk you if this do i can how <sos>
# 	loss: 0.00259574968367815
# 	input_sentence: <sos> <unk> <unk> . <eos>
# 	output_sentence: <eos> . <unk> <unk> <sos>
# 	loss: 0.002514817053452134
# 	input_sentence: <sos> - oh , i do n't think i could do that . <eos>
# 	output_sentence: <eos> . that do could i think n't do i , oh - <sos>
# 	loss: 0.009440800175070763
# 	input_sentence: <sos> look at that do n't you find the cover good ? <eos>
# 	output_sentence: <eos> ? good cover the find you n't do that at look <sos>
# 	loss: 0.00041854919982142746
# 	input_sentence: <sos> this is the front door , they will wait here in no case <eos>
# 	output_sentence: <eos> case no in here wait will they , door front the is this <sos>
# 	loss: 0.000832003599498421
# 	input_sentence: <sos> they probably got lost in the <unk> . <eos>
# 	output_sentence: <eos> . <unk> the in lost got probably they <sos>
# 	loss: 0.017855850979685783
# 	input_sentence: <sos> a little air will do you good . <eos>
# 	output_sentence: <eos> . good you do will air little a <sos>
# 	loss: 0.002097160555422306
# 	input_sentence: <sos> make sure to go in and rest . <eos>
# 	output_sentence: <eos> . rest and in go to sure make <sos>
# 	loss: 0.0037258360534906387
# 	input_sentence: <sos> i mean , magazines . <eos>
# 	output_sentence: <eos> . magazines , mean i <sos>
# 	loss: 0.006115991156548262
# 	input_sentence: <sos> i hear you 're being punished . <eos>
# 	output_sentence: <eos> . punished being 're you hear i <sos>
# 	loss: 0.0006520904134958982
# 	input_sentence: <sos> well .. <unk> started school , mr <unk> . <eos>
# 	output_sentence: <eos> . <unk> mr , school started <unk> .. well <sos>
# 	loss: 0.0009079848532564938
# 	input_sentence: <sos> hey , <unk> . <eos>
# 	output_sentence: <eos> . <unk> , hey <sos>
# 	loss: 0.0008992534130811691
# 	input_sentence: <sos> <unk> - <unk> ! <eos>
# 	output_sentence: <eos> ! <unk> - <unk> <sos>
# 	loss: 0.0031271714251488447
# 	input_sentence: <sos> no , it was a laugh . <eos>
# 	output_sentence: <eos> . laugh a was it , no <sos>
# 	loss: 0.002496343804523349
# 	input_sentence: <sos> take me and i 'll make a home for you . <eos>
# 	output_sentence: <eos> . you for home a make 'll i and me take <sos>
# 	loss: 0.005470857955515385
# 	input_sentence: <sos> <unk> . <eos>
# 	output_sentence: <eos> . <unk> <sos>
# 	loss: 0.0016934359446167946
# 	input_sentence: <sos> come along . <eos>
# 	output_sentence: <eos> . along come <sos>
# 	loss: 0.005117321386933327
# 	input_sentence: <sos> the reason is a <unk> rock - bound island as <unk> and <unk> as her queen ... who secretly gives aid to our enemies while her pirates <unk> our <unk> . <eos>
# 	output_sentence: <eos> . <unk> our <unk> pirates her while enemies our to aid gives secretly who ... queen her as <unk> and <unk> as island bound - rock <unk> a is reason the <sos>
# 	loss: 0.0016537262126803398
# 	input_sentence: <sos> well , that means another two weeks in <unk> . <eos>
# 	output_sentence: <eos> . <unk> in weeks two another means that , well <sos>
# 	loss: 0.0004745705227833241
# 	input_sentence: <sos> <unk> ! <eos>
# 	output_sentence: <eos> ! <unk> <sos>
# 	loss: 0.0015284225810319185
# 	input_sentence: <sos> i only had to give him 10 percent of the field . <eos>
# 	output_sentence: <eos> . field the of percent 10 him give to had only i <sos>
# 	loss: 0.002230824436992407
# 	input_sentence: <sos> oh , perhaps , he has n't thought of it . <eos>
# 	output_sentence: <eos> . it of thought n't has he , perhaps , oh <sos>
# Epoch 5/10, Loss: 0.2112
# 	loss: 0.0019589788280427456
# 	input_sentence: <sos> that 's a <unk> , <unk> . <eos>
# 	output_sentence: <eos> . <unk> , <unk> a 's that <sos>
# 	loss: 0.001977392006665468
# 	input_sentence: <sos> i shall offer my services for what they are worth . what about your rats ? <eos>
# 	output_sentence: <eos> ? rats your about what . worth are they what for services my offer shall i <sos>
# 	loss: 0.0007065750542096794
# 	input_sentence: <sos> thanks . <eos>
# 	output_sentence: <eos> . thanks <sos>
# 	loss: 0.004337314050644636
# 	input_sentence: <sos> it 's been my dream . <eos>
# 	output_sentence: <eos> . dream my been 's it <sos>
# 	loss: 0.0007017192547209561
# 	input_sentence: <sos> asking <unk> <unk> to attend to a dying person ! <eos>
# 	output_sentence: <eos> ! person dying a to attend to <unk> <unk> asking <sos>
# 	loss: 0.0014329188270494342
# 	input_sentence: <sos> - <unk> stepped out for a minute , miss <unk> . <eos>
# 	output_sentence: <eos> . <unk> miss , minute a for out stepped <unk> - <sos>
# 	loss: 0.00846930593252182
# 	input_sentence: <sos> i ca n't quite agree with you , sir <unk> . <eos>
# 	output_sentence: <eos> . <unk> sir , you with agree quite n't ca i <sos>
# 	loss: 0.003450560849159956
# 	input_sentence: <sos> it grows strong . <eos>
# 	output_sentence: <eos> . strong grows it <sos>
# 	loss: 0.0053246235474944115
# 	input_sentence: <sos> i have n't thought about the trip much . <eos>
# 	output_sentence: <eos> . much trip the about thought n't have i <sos>
# 	loss: 0.0004511273291427642
# 	input_sentence: <sos> oh . i guess you must be pretty old . <eos>
# 	output_sentence: <eos> . old pretty be must you guess i . oh <sos>
# 	loss: 0.000975420989561826
# 	input_sentence: <sos> - how would you say it ? <eos>
# 	output_sentence: <eos> ? it say you would how - <sos>
# 	loss: 0.00033308210549876094
# 	input_sentence: <sos> is it necessary ? <eos>
# 	output_sentence: <eos> ? necessary it is <sos>
# 	loss: 0.0024110169615596533
# 	input_sentence: <sos> this man would like to give you a present . <eos>
# 	output_sentence: <eos> . present a you give to like would man this <sos>
# 	loss: 0.0064152381382882595
# 	input_sentence: <sos> you 've handled this very <unk> , miss <unk> . <eos>
# 	output_sentence: <eos> . <unk> miss , <unk> very this handled 've you <sos>
# 	loss: 0.0004586914728861302
# 	input_sentence: <sos> - great fun . <eos>
# 	output_sentence: <eos> . fun great - <sos>
# 	loss: 0.007697881665080786
# 	input_sentence: <sos> up went our colors and our captain <unk> , " what ship is that ? " <eos>
# 	output_sentence: <eos> " ? that is ship what " , <unk> captain our and colors our went up <sos>
# 	loss: 0.0003440086729824543
# 	input_sentence: <sos> i was here with mr . <unk> and mr . <unk> . <eos>
# 	output_sentence: <eos> . <unk> . mr and <unk> . mr with here was i <sos>
# 	loss: 0.007493264973163605
# 	input_sentence: <sos> tonight . come the way you are . <eos>
# 	output_sentence: <eos> . are you way the come . tonight <sos>
# 	loss: 0.003993765451014042
# 	input_sentence: <sos> where duty calls , i go <eos>
# 	output_sentence: <eos> go i , calls duty where <sos>
# 	loss: 0.0057478840462863445
# 	input_sentence: <sos> oh , excuse me , sheriff . <eos>
# 	output_sentence: <eos> . sheriff , me excuse , oh <sos>
# 	loss: 0.0021872040815651417
# 	input_sentence: <sos> i 'll be fine on my own , okay ? <eos>
# 	output_sentence: <eos> ? okay , own my on fine be 'll i <sos>
# 	loss: 0.0007414888823404908
# 	input_sentence: <sos> but they shut you off room service . <eos>
# 	output_sentence: <eos> . service room off you shut they but <sos>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-b1d59964165f> in <cell line: 43>()
#      41
#      42 # Call the training function
# ---> 43 train(model, dataloader, optimizer, criterion, num_epochs=10)
#
# <ipython-input-31-b1d59964165f> in train(model, dataloader, optimizer, criterion, num_epochs)
#      34                 print(f"\toutput_sentence: {output_sentence}")
#      35
# ---> 36             epoch_loss += loss.item() * labels.size(0)  # Multiply by the number of entries
#      37
#      38         epoch_loss /= len(dataloader.dataset)  # Average the loss
#
# KeyboardInterrupt:

# %%
# Print input sentence without pad tokens
# Print the iteration of the loss
# Print accruacy (succesfully inverted sentences) per X batchs
# Create train, test sets. Evaluate accuracy on test set

# %%
model = model.cpu()
model.eval()
# Out:
# TransformerModel(
#   (embedding): Embedding(10004, 512)
#   (pos_encoder): Embedding(200, 512)
#   (transformer): Transformer(
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-2): 3 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#           )
#           (linear1): Linear(in_features=512, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=512, bias=True)
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): TransformerDecoder(
#       (layers): ModuleList(
#         (0-2): 3 x TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#           )
#           (linear1): Linear(in_features=512, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=512, bias=True)
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (dropout3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (fc_out): Linear(in_features=512, out_features=10004, bias=True)
# )

# %%
torch.save(model.state_dict(), "model_state_dict.pt")
