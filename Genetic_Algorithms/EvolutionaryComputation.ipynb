# %%
import random

def start_population(length: int() = 9, size: int() = 4) -> str():
    population = [''.join([str(random.randint(0, 1)) for x in range(1, length + 1)]) for i in range(size)]
    return population

def bin2dec(binary_list: list()) -> list():
    return [int(binary_str, 2) for binary_str in binary_list]

def map2real(chromosome_str: str()):

    split_chr = []

# %%
n_chromosomes = 3
x = start_population()
print(x)
# Out:
# ['010101110', '011101011', '110001001', '100000000']

# %%
y = bin2dec(x)
y
# Out:
# [174, 235, 393, 256]

# %%
def prob_selection(population: dict()) -> dict():
    data = [value for value in population.values()]
    total = sum(data[i][1] for i in range(len(data)))
    for key in population.keys():
        population[key].append(population[key][1] / total)
    return(population)


population = {
    "011100001": [[2.143, 2.857, 0.714], 4.373],
    "011011001": [[2.143, 2.143, 0.714], 3.279],
    "001011001": [[0.714, 2.143, 0.714], 1.093],
    "001010100": [[0.714, 1.429, 2.857], 2.915]

}

population = prob_selection(population)
population
# Out:
# {'011100001': [[2.143, 2.857, 0.714], 4.373, 0.3750428816466552],
#  '011011001': [[2.143, 2.143, 0.714], 3.279, 0.28121783876500855],
#  '001011001': [[0.714, 2.143, 0.714], 1.093, 0.0937392795883362],
#  '001010100': [[0.714, 1.429, 2.857], 2.915, 0.25]}

# %%
p1 = [16.71, 76.30, 18.18, 0.92]
p2 = [44.21, 64.32, 19.48, 15.01]

# c1 - Mean
s1 = [0.5*p1[i] + 0.5*p2[i] for i in range(len(p1))]
print(s1)

# c2 extrapolation to p1
s2 = [1.5*p1[i] - 0.5*p2[i] for i in range(len(p1))]
print(s2)

# c3 extrapolation to p2
s3 = [1.5*p2[i] - 0.5*p1[i] for i in range(len(p1))]
print(s3)
# Out:
# [30.46, 70.31, 18.83, 7.965]
# [2.960000000000001, 82.28999999999999, 17.53, -6.125]
# [57.959999999999994, 58.32999999999999, 20.13, 22.055]
